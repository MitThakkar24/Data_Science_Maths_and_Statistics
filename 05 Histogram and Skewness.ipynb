# %%
import seaborn as sns
import numpy as np

# %%
Ages = {10,12,14,18,24,26,20,35,36,37,40,41,42,43,50,51}

# %%
sns.histplot(Ages,bins=5,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [raw]
# -> Probability Distribution Function
# -> Probability density function - PDF

# %% [raw]
# 1) Guassian Distribution
# -> Normal Distribution
# -> Symmetircal Distribution
#
# -> Bell Curve
# -> 50% Distribution left and right
# -> No Skewness
#
# -> The Mean, Median and Mode all are perfectly centered
# -> Mean = Median = Mode
#
# -> In Box Plot
# -> Q3 - Q2 ~= Q2 -Q1

# %%
ages = {10, 12, 14, 18, 24, 26, 20, 35, 36, 37, 40, 41, 42, 43, 50, 51}

# %%
sns.histplot(np.random.normal(0, 1, 10),bins=5,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [raw]
# 2) Right Skewed Data
# -> Positive Skewed
# -> Mean > Median > Mode

# %%
right_skewed_data = [3, 4, 4, 5, 5, 5, 6, 6, 6, 6, 7, 7, 7, 7, 7, 8, 8, 8, 8, 8, 8, 9, 9, 9, 9, 9, 9, 9, 10, 10, 10, 10, 10, 10, 10, 10, 11, 11, 11, 11, 11, 11, 11, 12, 12, 12, 12, 12, 13, 13, 13, 13, 14]
sns.histplot(right_skewed_data,bins=5,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.boxplot(right_skewed_data)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
3) Left Skewed Distribution
-> Negative Skewed
-> Mean < Median < Mode

# %%
sns.histplot(np.random.normal(0, 1, 10),bins=5,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>
